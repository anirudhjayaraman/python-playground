# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
mydata = ['Boat', 'Car', 'Bike', 'Truck']
myseries1 = pd.Series(data = mydata)

# %%
print(myseries1)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %% [markdown]
# Every series has an index
# The dtype is the type of object in this series. Strings result in 'object' types

# %%
mydata = [1, 55, 9, 49, 43]
myseries2 = pd.Series(data = mydata)
print(myseries2)
# Out:
# 0     1
# 1    55
# 2     9
# 3    49
# 4    43
# dtype: int64

# %% [markdown]
# Above, the dtype is int64

# %% [markdown]
# ## DataFrames

# %% [markdown]
# Grouping of multiple series, all linked by an index

# %%
mydfdata = [('Boat', 1), ('Car', 55), ('Bike',9), ('Truck',99)]
mydf = pd.DataFrame(data = mydfdata)
print(mydfdata)
print(mydf)
# Out:
# [('Boat', 1), ('Car', 55), ('Bike', 9), ('Truck', 99)]
#        0   1
# 0   Boat   1
# 1    Car  55
# 2   Bike   9
# 3  Truck  99

# %% [markdown]
# These are two different Series within a dataset (dataframe).
# Rows are the index
# Dummy column names 0 and 1 should be changed

# %%
mydf = pd.DataFrame(data = mydfdata, columns=['Thing','Count'])
mydf
# Out:
#    Thing  Count
# 0   Boat      1
# 1    Car     55
# 2   Bike      9
# 3  Truck     99

# %%
mydf['Thing']
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# Name: Thing, dtype: object

# %%
print(mydf["Thing"])
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# Name: Thing, dtype: object

# %%
mydf['Count']
# Out:
# 0     1
# 1    55
# 2     9
# 3    99
# Name: Count, dtype: int64

# %%
mydf.dtypes
# Out:
# Thing    object
# Count     int64
# dtype: object

# %% [markdown]
# dtypes tells you the data types for individual columns / Series of the dataframe

# %% [markdown]
# ## Reading in Data

# %%
df = pd.read_csv('./data/MrBeast_youtube_stats.csv')

# %% [markdown]
# ## Inspect the Data

# %%
df.head(n = 3)
# Out:
#             id                                     title  \
# 0  Y74b7WlcEpk                 More birds IN MINECRAFT!!
# 1  63gyUQ_JeOE     Toothpaste Life Hacks YOU SHOULD KNOW
# 2  Rj_vssRaZlQ  I Ate The World’s Largest Slice Of Pizza
#
#                                          description  \
# 0  Basically what this mod does is adds more bird...
# 1  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# 2  This slice of pizza was expensive... New Merch...
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2013-01-12 23:35:45+00:00  youtube#video               126     692040.0
# 1  2017-06-13 22:30:01+00:00  youtube#video               283   19644553.0
# 2  2020-08-01 20:00:02+00:00  youtube#video               483  150392896.0
#
#    likeCount  commentCount                          thumbnails.default.url  \
# 0    29037.0        2986.0  https://i.ytimg.com/vi/Y74b7WlcEpk/default.jpg
# ...

# %%
df.dtypes
# Out:
# id                               object
# title                            object
# description                      object
# publishTime                      object
# kind_stats                       object
# duration_seconds                  int64
# viewCount                       float64
# likeCount                       float64
# commentCount                    float64
# thumbnails.default.url           object
# thumbnails.default.width        float64
# thumbnails.default.height       float64
# thumbnails.medium.url            object
# thumbnails.medium.width         float64
# thumbnails.medium.height        float64
# thumbnails.high.url              object
# thumbnails.high.width           float64
# thumbnails.high.height          float64
# contentDetails.duration          object
# contentDetails.dimension         object
# topicDetails.topicCategories     object
# snippet.defaultLanguage          object
# localizations.en.title           object
# ...

# %%
df.describe()
# Out:
#        duration_seconds     viewCount     likeCount   commentCount  \
# count      63296.000000  6.323400e+04  6.316500e+04   62995.000000
# mean        1859.596515  5.673657e+07  1.688326e+06   73762.437416
# std         8381.425204  4.649452e+07  1.876497e+06   78486.790047
# min            0.000000  1.401300e+04  0.000000e+00       0.000000
# 25%          431.000000  1.514796e+07  4.833680e+05   22909.000000
# 50%          788.000000  5.269076e+07  1.420298e+06   61870.000000
# 75%          924.000000  8.983069e+07  2.472583e+06  101265.500000
# max        86402.000000  3.146955e+08  2.088475e+07  734726.000000
#
#        thumbnails.default.width  thumbnails.default.height  \
# count                   63291.0                    63291.0
# mean                      120.0                       90.0
# std                         0.0                        0.0
# min                       120.0                       90.0
# 25%                       120.0                       90.0
# ...

# %%
df['viewCount']
# Out:
# 0           692040.0
# 1         19644553.0
# 2        150392896.0
# 3         49236088.0
# 4        133035761.0
#             ...
# 63291        18606.0
# 63292     82808860.0
# 63293        18834.0
# 63294        16701.0
# 63295     26259668.0
# Name: viewCount, Length: 63296, dtype: float64

# %%
df.loc[4] # Gives me the 4th row
# Out:
# id                                                                    HBMmK1c44sE
# title                                       I Spent 24 Hours In A Doomsday Bunker
# description                     The bunker gets crazier as the video goes on! ...
# publishTime                                             2020-04-11 20:00:00+00:00
# kind_stats                                                          youtube#video
# duration_seconds                                                              719
# viewCount                                                             133035761.0
# likeCount                                                               2506329.0
# commentCount                                                              79981.0
# thumbnails.default.url             https://i.ytimg.com/vi/HBMmK1c44sE/default.jpg
# thumbnails.default.width                                                    120.0
# ...

# %%
df.loc[0:4] # equivalent of df.head()
# Out:
#             id                                              title  \
# 0  Y74b7WlcEpk                          More birds IN MINECRAFT!!
# 1  63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# 2  Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# 3  wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# 4  HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
#
#                                          description  \
# 0  Basically what this mod does is adds more bird...
# 1  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# 2  This slice of pizza was expensive... New Merch...
# 3  YOU WONT BELIEVE WHO WON THIS New Merch - http...
# 4  The bunker gets crazier as the video goes on! ...
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2013-01-12 23:35:45+00:00  youtube#video               126     692040.0
# 1  2017-06-13 22:30:01+00:00  youtube#video               283   19644553.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=63296, step=1)

# %%
df.set_index(keys = ['id'], inplace = True)

# %%
df.head(3)
# Out:
#                                                 title  \
# id
# Y74b7WlcEpk                 More birds IN MINECRAFT!!
# 63gyUQ_JeOE     Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ  I Ate The World’s Largest Slice Of Pizza
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# Rj_vssRaZlQ  This slice of pizza was expensive... New Merch...
#
#                            publishTime     kind_stats  duration_seconds  \
# id
# Y74b7WlcEpk  2013-01-12 23:35:45+00:00  youtube#video               126
# 63gyUQ_JeOE  2017-06-13 22:30:01+00:00  youtube#video               283
# Rj_vssRaZlQ  2020-08-01 20:00:02+00:00  youtube#video               483
#
#                viewCount  likeCount  commentCount  \
# id
# Y74b7WlcEpk     692040.0    29037.0        2986.0
# 63gyUQ_JeOE   19644553.0   506401.0       15890.0
# ...

# %%
list(df.columns)
# Out:
# ['title',
#  'description',
#  'publishTime',
#  'kind_stats',
#  'duration_seconds',
#  'viewCount',
#  'likeCount',
#  'commentCount',
#  'thumbnails.default.url',
#  'thumbnails.default.width',
#  'thumbnails.default.height',
#  'thumbnails.medium.url',
#  'thumbnails.medium.width',
#  'thumbnails.medium.height',
#  'thumbnails.high.url',
#  'thumbnails.high.width',
#  'thumbnails.high.height',
#  'contentDetails.duration',
#  'contentDetails.dimension',
#  'topicDetails.topicCategories',
#  'snippet.defaultLanguage',
#  'localizations.en.title',
#  'localizations.en.description',
#  'snippet.tags',
#  'pull_date']

# %%
df[['title',
 'description',
 'publishTime',
 'duration_seconds',
 'viewCount',
 'likeCount',
 'commentCount']]
# Out:
#                                                          title  \
# id
# Y74b7WlcEpk                          More birds IN MINECRAFT!!
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# ...                                                        ...
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# ...

# %%
df = df[['title',
 'description',
 'publishTime',
 'duration_seconds',
 'viewCount',
 'likeCount',
 'commentCount']]

df.shape
# Out:
# (63296, 7)

# %%
# Subsetting Rows

df_subset_1 = df.loc[df.viewCount > 1e6,:]
df_subset_1
# Out:
#                                                          title  \
# id
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# Rj_vssRaZlQ  This slice of pizza was expensive... New Merch...
# ...

# %%
df.query('viewCount > 1e6')
# Out:
#                                                          title  \
# id
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# cExLQ1o2pDw                    First To Rob Bank Wins $100,000
# ...                                                        ...
# 9CVwXBYVqVk                Counting To 200,000 (Road To A Mil)
# 2IGxSOfsBok                              I Hate Pewdiepie!!!!!
# bEIK5ni_Pzs   How Many People Get The Diamond Play Button?????
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# Rj_vssRaZlQ  This slice of pizza was expensive... New Merch...
# ...

# %%
df
# Out:
#                                                          title  \
# id
# Y74b7WlcEpk                          More birds IN MINECRAFT!!
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# ...                                                        ...
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# ...

# %%
df['viewCount'].isna()
# Out:
# id
# Y74b7WlcEpk    False
# 63gyUQ_JeOE    False
# Rj_vssRaZlQ    False
# wMuYiLby3-s    False
# HBMmK1c44sE    False
#                ...
# AIytwdufwW8    False
# RCvnytndd9c    False
# zi7tZ-2PhLk    False
# 56OkH6ocYZU    False
# 3iaDrpKdaIc    False
# Name: viewCount, Length: 63296, dtype: bool

# %%
~df.viewCount.isna()
# Out:
# id
# Y74b7WlcEpk    True
# 63gyUQ_JeOE    True
# Rj_vssRaZlQ    True
# wMuYiLby3-s    True
# HBMmK1c44sE    True
#                ...
# AIytwdufwW8    True
# RCvnytndd9c    True
# zi7tZ-2PhLk    True
# 56OkH6ocYZU    True
# 3iaDrpKdaIc    True
# Name: viewCount, Length: 63296, dtype: bool

# %%
df = df.loc[~df.viewCount.isna()]

# %%
df
# Out:
#                                                          title  \
# id
# Y74b7WlcEpk                          More birds IN MINECRAFT!!
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
# ...                                                        ...
# AIytwdufwW8   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# ...

# %% [markdown]
# ## Casting dtypes

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount           float64
# likeCount           float64
# commentCount        float64
# dtype: object

# %%
df.viewCount = df.viewCount.astype('int')
# Out:
# /Users/anirudhjayaraman/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.dtypes
# Out:
# title                object
# description          object
# publishTime          object
# duration_seconds      int64
# viewCount             int64
# likeCount           float64
# commentCount        float64
# dtype: object

# %%
df.loc[:,['publishTime']] = pd.to_datetime(df['publishTime'])
# Out:
# /Users/anirudhjayaraman/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                       float64
# commentCount                    float64
# dtype: object

# %%
df['likeCount'] = pd.to_numeric(df['likeCount']).astype('str')
# Out:
# <ipython-input-80-079c9527cde8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['likeCount'] = pd.to_numeric(df['likeCount']).astype('str')

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                        object
# commentCount                    float64
# dtype: object

# %%
df.head(2)
# Out:
#                                              title  \
# id
# Y74b7WlcEpk              More birds IN MINECRAFT!!
# 63gyUQ_JeOE  Toothpaste Life Hacks YOU SHOULD KNOW
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
#
#                           publishTime  duration_seconds  viewCount likeCount  \
# id
# Y74b7WlcEpk 2013-01-12 23:35:45+00:00               126     692040   29037.0
# 63gyUQ_JeOE 2017-06-13 22:30:01+00:00               283   19644553  506401.0
#
#              commentCount
# id
# Y74b7WlcEpk        2986.0
# 63gyUQ_JeOE       15890.0

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                        object
# commentCount                    float64
# dtype: object

# %%
df.loc[:,['likeCount']] =  df['likeCount'].astype('float64')
# Out:
# /Users/anirudhjayaraman/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                       float64
# commentCount                    float64
# dtype: object

# %% [markdown]
# ### Creating a new column

# %%
df['like_to_view'] = df['likeCount'] / df['viewCount']
df.head()
# Out:
# <ipython-input-95-4adfa0c57083>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['like_to_view'] = df['likeCount'] / df['viewCount']
#                                                          title  \
# id
# Y74b7WlcEpk                          More birds IN MINECRAFT!!
# 63gyUQ_JeOE              Toothpaste Life Hacks YOU SHOULD KNOW
# Rj_vssRaZlQ           I Ate The World’s Largest Slice Of Pizza
# wMuYiLby3-s  Last To Stop Riding Bike Wins $1,000,000 (Part 4)
# HBMmK1c44sE              I Spent 24 Hours In A Doomsday Bunker
#
#                                                    description  \
# id
# Y74b7WlcEpk  Basically what this mod does is adds more bird...
# 63gyUQ_JeOE  I CAN'T BELIEVE IT WORKED HOLY CRAP SUBSCRIBE ...
# ...

# %%
df.tail(1)
# Out:
#                                         title  \
# id
# 3iaDrpKdaIc  I Ubered Random People In A Tank
#
#                                                    description  \
# id
# 3iaDrpKdaIc  YOU WON'T BELIEVE HOW THEY REACTED! New Merch ...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# 3iaDrpKdaIc 2018-07-11 21:16:00+00:00               604   26259668   719806.0
#
#              commentCount  like_to_view
# id
# 3iaDrpKdaIc       44780.0      0.027411

# %% [markdown]
# ### Concatenating datasets

# %%
df2 = pd.concat([df, df.tail(1)])

# %%
df2.tail()
# Out:
#                                                          title  \
# id
# RCvnytndd9c                      Last To Leave VR Wins $20,000
# zi7tZ-2PhLk  How Much Money Do You Make As An Uber Driver??...
# 56OkH6ocYZU    L0114R - Biblical Creeper Post for Post @L0114R
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
# 3iaDrpKdaIc                   I Ubered Random People In A Tank
#
#                                                    description  \
# id
# RCvnytndd9c  YOU WON'T BELIEVE HOW LONG THEY LASTED!!! New ...
# zi7tZ-2PhLk  In this video I talk about being an uber drive...
# 56OkH6ocYZU  His channel - https://www.youtube.com/user/the...
# 3iaDrpKdaIc  YOU WON'T BELIEVE HOW THEY REACTED! New Merch ...
# 3iaDrpKdaIc  YOU WON'T BELIEVE HOW THEY REACTED! New Merch ...
#
#                           publishTime  duration_seconds  viewCount  likeCount  \
# id
# RCvnytndd9c 2019-06-08 20:00:01+00:00               858   82808860  1910890.0
# ...

# %% [markdown]
# ### Plot Examples

# %%
df.dtypes
# Out:
# title                            object
# description                      object
# publishTime         datetime64[ns, UTC]
# duration_seconds                  int64
# viewCount                         int64
# likeCount                       float64
# commentCount                    float64
# like_to_view                    float64
# dtype: object

# %%
df['viewCount'].plot(kind = 'hist', bins = 50, title = 'Distribution of View Count',
                    figsize = (10,5))
# Out:
# <AxesSubplot:title={'center':'Distribution of View Count'}, ylabel='Frequency'>

# %%
df.plot(kind = 'scatter', x = 'viewCount', y = 'likeCount', title = 'View vs Like Count')
# Out:
# <AxesSubplot:title={'center':'View vs Like Count'}, xlabel='viewCount', ylabel='likeCount'>

# %%
df.query('likeCount > 10e6').plot(kind = 'scatter', x = 'viewCount', y = 'likeCount', title = 'View vs Like Count for Likes > 10mn')
# Out:
# <AxesSubplot:title={'center':'View vs Like Count for Likes > 10mn'}, xlabel='viewCount', ylabel='likeCount'>

# %% [markdown]
# The above plot shows that views and likes move in tandem at varying rates (slopes) depending on the video.
# Surprisingly, videos with the highest like count

# %%
df.query('likeCount > 10e6')
# Out:
#                 id                                            title  \
# 43     S_CUEOBZ0P4                 The Rock Vs MrBeast For $100,000
# 68     0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 138    YlvcFJOE-OE     Giving iPhones Instead Of Candy on Halloween
# 244    0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 343    dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
# ...            ...                                              ...
# 62752  dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
# 62850  0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 62999  dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
# 63097  0e3GPea1Tyg                $456,000 Squid Game In Real Life!
# 63246  dBxOYE2j55U  Make This Video The Most Liked Video On Youtube
#
#                                              description  \
# 43     Winning totally Rocks! New Merch - https://sho...
# ...
